# %%
import pandas as pd
import numpy as np
tips=pd.read_csv('BD3.csv')

# %%
import pandas as pd

def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-39d4999a1fae> in <module>
# ----> 1 X = X.as_matrix().astype(np.float)
#
# NameError: name 'X' is not defined

# %%
y = y.as_matrix().astype(np.float)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-39d4999a1fae> in <module>
# ----> 1 X = X.as_matrix().astype(np.float)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'as_matrix'

# %%
X = tips[['iyear','attacktype1','targtype1','targsubtype1','weaptype1','INT_ANY','property']]

# %%
y=tips['nkill']

# %%
y = y.as_matrix().astype(np.float)
# Out:
# C:\Users\DPE\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
X = X.as_matrix().astype(np.float)
# Out:
# C:\Users\DPE\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
clean_dataset(X_train)
# Out:
# C:\Users\DPE\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#        iyear  attacktype1  targtype1  targsubtype1  weaptype1  INT_ANY  \
# 1110  2015.0          3.0       14.0          68.0        6.0     -9.0
# 1387  2015.0          3.0        3.0          22.0        6.0      0.0
# 823   2013.0          7.0       14.0          73.0        8.0      0.0
# 666   2006.0          3.0       14.0          75.0        6.0     -9.0
# 1472  2015.0          2.0       14.0          68.0        5.0      1.0
# 1029  2014.0          3.0        8.0          50.0        6.0     -9.0
# 1617  2017.0          3.0        3.0          22.0        6.0      0.0
# 1458  2015.0          1.0       22.0         109.0        5.0     -9.0
# 1201  2015.0          3.0       14.0          70.0        6.0      0.0
# 202   1992.0          1.0        2.0          15.0        5.0     -9.0
# 69    1989.0          3.0        1.0           2.0        6.0      0.0
# 1294  2015.0          7.0       19.0          99.0        8.0     -9.0
# 938   2014.0          7.0        2.0          19.0        8.0     -9.0
# 981   2014.0          3.0       15.0          86.0        6.0     -9.0
# 159   1991.0          3.0        2.0          14.0        6.0     -9.0
# 499   1996.0          9.0       14.0          73.0       13.0     -9.0
# 327   1995.0          1.0        2.0          18.0        5.0     -9.0
# 352   1995.0          3.0        3.0          25.0        6.0     -9.0
# 1241  2015.0          3.0       19.0          99.0        6.0      0.0
# 1250  2015.0          7.0       19.0         100.0        8.0      0.0
# 628   2005.0          3.0       10.0          53.0        6.0      1.0
# 1052  2015.0          1.0       14.0          84.0        6.0     -9.0
# 693   2008.0          2.0        3.0          25.0        5.0      0.0
# 118   1991.0          6.0       22.0         109.0        5.0     -9.0
# 1134  2015.0          3.0        8.0          49.0        6.0     -9.0
# 889   2013.0          1.0        2.0          18.0        6.0     -9.0
# 1098  2015.0          3.0        2.0          14.0        6.0     -9.0
# 57    1988.0          2.0       14.0          75.0        5.0      0.0
# 251   1994.0          8.0        3.0          23.0        9.0      0.0
# 1500  2015.0          7.0        1.0           1.0       13.0      0.0
# ...      ...          ...        ...           ...        ...      ...
# 1465  2015.0          3.0       14.0          68.0        6.0     -9.0
# 4     1982.0          3.0       22.0         109.0        6.0     -9.0
# 571   2000.0          3.0       14.0          82.0        6.0     -9.0
# 750   2011.0          2.0       17.0          93.0        5.0     -9.0
# 487   1996.0          9.0       14.0          84.0       13.0     -9.0
# 1393  2015.0          3.0        8.0          49.0        6.0     -9.0
# 1252  2015.0          3.0        3.0          23.0        6.0      0.0
# 758   2011.0          3.0       14.0          67.0        6.0     -9.0
# 1232  2015.0          7.0       19.0          99.0        8.0      0.0
# 1445  2015.0          3.0       22.0         110.0        6.0     -9.0
# 1162  2015.0          3.0       14.0          77.0        6.0     -9.0
# 786        1.0
# 1390       0.0
# 5          0.0
# 1160      -9.0
# 913        1.0
# 15         1.0
# 1330      -9.0
# 174        1.0
# ...        ...
# 1548       1.0
# 752        0.0
# 434        1.0
# 1060      -9.0
# 723        0.0
# 395        1.0
# 815       -9.0
# 11         1.0
# 403        1.0
# 1          1.0
# 755        1.0
# 1076       1.0
# 173        1.0
# 353        0.0
# 1089      -9.0
# 367        1.0
# 1013       0.0
# 102        1.0
# 1199      -9.0
# 874        1.0
# 438        1.0
# 562        0.0
# 1603       1.0
# 120        1.0
# 1273       0.0
# 717       -9.0
# 857        1.0
# 998        1.0
# 402        1.0
# 112        1.0
#
# [451 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-1e563c7b3c38> in <module>
# ----> 1 y = y.as_matrix().astype(np.float)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'as_matrix'

# %%
clean_dataset(y_train)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-88-359af3a8dce8> in <module>
# ----> 1 clean_dataset(y_train)
#
# <ipython-input-79-c95c0b12d481> in clean_dataset(df)
#       2
#       3 def clean_dataset(df):
# ----> 4     assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
#       5     df.dropna(inplace=True)
#       6     indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
#
# AssertionError: df needs to be a pd.DataFrame

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-a16f7a4d5962> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 clf = LinearRegression()
# ----> 3 clf.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
X_test
# Out:
#       iyear  attacktype1  targtype1  targsubtype1  weaptype1  INT_ANY  \
# 462    1996            2         14          84.0          5       -9
# 967    2014            3          2          19.0          6       -9
# 1426   2015            3          3          22.0          6       -9
# 541    1997            2          8          49.0          5        0
# 1555   2016            3         14          74.0          6       -9
# 1000   2014            2         22         109.0          5        0
# 78     1989            3         11          57.0          6        0
# 1375   2015            3          8          49.0          6       -9
# 1491   2015            1         22         109.0          6        0
# 1140   2015            2          3          23.0          6       -9
# 340    1995            3         14          84.0          6       -9
# 1074   2015            1          2          14.0          6       -9
# 1367   2015            3         14          67.0          6       -9
# 598    2001            3         14          78.0          6       -9
# 968    2014            3          2          19.0          6       -9
# 191    1992            2         19          99.0          8        0
# 756    2011            3         19         100.0          6       -9
# 319    1995            2         19          99.0          8       -9
# 1629   2017            2          2          15.0          9       -9
# 1562   2016            2          8          48.0          9        1
# 145    1991            2          2          15.0          5        0
# 1582   2016            3         14          76.0          6       -9
# 786    2013            7         14          73.0          8       -9
# 1390   2015            3          1           3.0          6        0
# 5      1984            1          2          15.0          9       -9
# 1160   2015            3         19         105.0          6        0
# 913    2013            3          2          14.0          6        0
# 15     1986            3         14          75.0         13       -9
# 1330   2015            3         14          67.0          6       -9
# 174    1992            2          8          50.0          5        0
# ...     ...          ...        ...           ...        ...      ...
# 1548   2016            7         14          69.0          8       -9
# 752    2011            2         17          93.0          5       -9
# 434    1996            7         19         100.0          8       -9
# 1060   2015            3          2          14.0          6       -9
# 723    2009            2         17          93.0          9       -9
# 395    1996            9         14          84.0         13       -9
# 815    2013            3          8          49.0          6        0
# 11     1986            2          3          22.0          5        0
# 403    1996            2         19         105.0          8       -9
# 1      1979            6          7          45.0          5        1
# 755    2011            7          8          49.0          8        0
# 1076   2015            7         19          99.0          8        0
# 173    1992            2          8          50.0          5        0
# 353    1995            1         14          84.0         13        0
# 1089   2015            3          8          49.0          6       -9
# 367    1995            3          2          17.0          6       -9
# 1013   2014            6          2          15.0         13       -9
# 102    1990            2         14          77.0          5        0
# 1199   2015            3         14          68.0          6       -9
# 874    2013            1          2          15.0          6       -9
# 438    1996            9         19         100.0         13       -9
# 562    1999            2         14          67.0          5        0
# 1603   2016            7         14          69.0          8       -9
# 120    1991            3          3          25.0          6       -9
# 1273   2015            3         17          94.0          6       -9
# 717    2009            8          8          50.0          9        0
# 857    2013            3          3          25.0          6       -9
# 998    2014            7          1           7.0          8       -9
# 402    1996            9         14          74.0         13       -9
# 112    1990            2          2          21.0          8        1
#
#       property
# 462          1
# 967         -9
# 1426        -9
# 541          1
# 1555        -9
# 1000         0
# 78           1
# 1375        -9
# 1491         0
# 1140         1
# 340          1
# 1074        -9
# 1367        -9
# 598         -9
# 968         -9
# 191          1
# 756          0
# 319          1
# 1629         0
# 1562         0
# 145          1
# 1582         1
# 786          1
# 1390         0
# 5            0
# 1160        -9
# 913          1
# 15           1
# 1330        -9
# 174          1
# ...        ...
# 1548         1
# 752          0
# 434          1
# 1060        -9
# 723          0
# 395          1
# 815         -9
# 11           1
# 403          1
# 1            1
# 755          1
# 1076         1
# 173          1
# 353          0
# 1089        -9
# 367          1
# 1013         0
# 102          1
# 1199        -9
# 874          1
# 438          1
# 562          0
# 1603         1
# 120          1
# 1273         0
# 717         -9
# 857          1
# 998          1
# 402          1
# 112          1
#
# [451 rows x 7 columns]

# %%
clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-91-f649b58415e1> in <module>
# ----> 1 clf.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     192
#     193     def _decision_function(self, X):
# --> 194         check_is_fitted(self, "coef_")
#     195
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
y_test
# Out:
# 462      0.0
# 967      0.0
# 1426     0.0
# 541      0.0
# 1555     0.0
# 1000     1.0
# 281      0.0
# 78      16.0
# 1375     0.0
# 1491     0.0
# 1140     1.0
# 340      2.0
# 1074     0.0
# 1367     0.0
# 598      0.0
# 968      0.0
# 191      0.0
# 756      0.0
# 319      0.0
# 1629     0.0
# 1562     0.0
# 145      0.0
# 1582     1.0
# 786      0.0
# 1390     0.0
# 5        1.0
# 1160     0.0
# 913      0.0
# 15       4.0
# 1330     0.0
#         ...
# 1548     0.0
# 752      1.0
# 434      0.0
# 1060     0.0
# 723      3.0
# 395      0.0
# 815      0.0
# 11       NaN
# 403      1.0
# 1        0.0
# 755      0.0
# 1076     0.0
# 173      0.0
# 353      1.0
# 1089     0.0
# 367      0.0
# 1013     1.0
# 102     20.0
# 1199     0.0
# 874      1.0
# 438      0.0
# 562      7.0
# 1603     0.0
# 120      3.0
# 1273     0.0
# 717      0.0
# 857      0.0
# 998      0.0
# 402      0.0
# 112      0.0
# Name: nkill, Length: 495, dtype: float64

# %%
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-93-84d2b7af5512> in <module>
#       1
# ----> 2 clf.score(X_test, y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     328
#     329         from .metrics import r2_score
# --> 330         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     331                         multioutput='variance_weighted')
#     332
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     192
#     193     def _decision_function(self, X):
# --> 194         check_is_fitted(self, "coef_")
#     195
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)
X_test
# Out:
#       iyear  attacktype1  targtype1  targsubtype1  weaptype1  INT_ANY  \
# 1426   2015            3          3          22.0          6       -9
# 278    1994            8         14          73.0          9        0
# 953    2014            7          2          19.0          8       -9
# 64     1989            1         14          83.0          6       -9
# 418    1996            7          2          19.0          8       -9
# 776    2012            1          2          18.0          5       -9
# 1080   2015            3          1           7.0          6       -9
# 123    1991            2         14          75.0          5        0
# 36     1988            1          2          15.0          5       -9
# 1128   2015            3         20           NaN          6        0
# 537    1996            6          2          18.0          5        0
# 1532   2016            2         10          56.0          5        1
# 1000   2014            2         22         109.0          5        0
# 1273   2015            3         17          94.0          6       -9
# 60     1989            6         14          67.0          5        1
# 819    2013            3          8          49.0          6        0
# 1606   2016            1          2          15.0          5        0
# 211    1992            9         15          86.0         13       -9
# 1540   2016            6         14          68.0          9        0
# 949    2014            7          2          19.0          8       -9
# 840    2013            3          8          49.0          6       -9
# 463    1996            9         14          84.0         13       -9
# 946    2014            7          2          19.0          8       -9
# 815    2013            3          8          49.0          6        0
# 809    2013            2         10          56.0          9        0
# 803    2013            3          8          49.0          6        0
# 1053   2015            3          1           7.0          6       -9
# 435    1996            7          2          21.0          8       -9
# 318    1995            2         19          99.0          8       -9
# 1639   2017            2         14          68.0          9       -9
# ...     ...          ...        ...           ...        ...      ...
# 691    2008            3         14          67.0          6       -9
# 1286   2015            3          8          49.0          6       -9
# 1042   2014            3         22         110.0          6       -9
# 1008   2014            1          2          15.0          6        0
# 471    1996            3         22         111.0          6       -9
# 1005   2014            2         22         109.0          6        0
# 1452   2015            3          1           8.0          6       -9
# 1636   2017            6         14          69.0          9        1
# 1207   2015            3         22         109.0          6       -9
# 1351   2015            3         14          68.0          6       -9
# 1428   2015            3          3          25.0          6       -9
# 39     1988            3          2          15.0          6       -9
# 679    2007            6         12          62.0          5       -9
# 742    2010            1         12          62.0          9       -9
# 188    1992            2         14          75.0          5        0
# 1238   2015            3         20           NaN          6       -9
# 1246   2015            2          3          23.0          6        0
# 423    1996            9          2          21.0         13       -9
# 489    1996            3         20           NaN          6       -9
# 1519   2016            7         22         110.0          8       -9
# 1332   2015            3         20           NaN          6        0
# 78     1989            3         11          57.0          6        0
# 179    1992            3          3          25.0          5        0
# 142    1991            9          2          15.0         13        0
# 1467   2015            3         15          87.0          6        0
# 643    2005            3          2          14.0          6        0
# 1173   2015            3         14          77.0          6       -9
# 202    1992            1          2          15.0          5       -9
# 1379   2015            3         20           NaN          6       -9
# 697    2008            2          1           NaN          5        0
#
#       property
# 1426        -9
# 278          1
# 953          1
# 64           0
# 418          1
# 776          1
# 1080         1
# 123          1
# 36           0
# 1128        -9
# 537          0
# 1532         0
# 1000         0
# 1273         0
# 60           0
# 819         -9
# 1606         0
# 211          1
# 1540         0
# 949          1
# 840         -9
# 463          1
# 946          1
# 815         -9
# 809          0
# 803         -9
# 1053        -9
# 435          1
# 318          1
# 1639         0
# ...        ...
# 691         -9
# 1286        -9
# 1042        -9
# 1008         1
# 471          1
# 1005         0
# 1452        -9
# 1636         0
# 1207         1
# 1351        -9
# 1428        -9
# 39           1
# 679          0
# 742          0
# 188          1
# 1238        -9
# 1246         0
# 423          1
# 489          1
# 1519         1
# 1332        -9
# 78           1
# 179          1
# 142          1
# 1467        -9
# 643          1
# 1173        -9
# 202          0
# 1379        -9
# 697         -9
#
# [495 rows x 7 columns]

# %%
y_train.fillna(y_train.mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-aa763bdd3685> in <module>
# ----> 1 y_train.fillna(y_train.mean())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'fillna'

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='poly', degree=8)
svclassifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-b71e5a957b08> in <module>
#       1 from sklearn.svm import SVC
#       2 svclassifier = SVC(kernel='poly', degree=8)
# ----> 3 svclassifier.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
X_train.fillna(X_train.mean(), inplace=True)
# Out:
# C:\Users\DPE\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='poly', degree=8)
svclassifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-b71e5a957b08> in <module>
#       1 from sklearn.svm import SVC
#       2 svclassifier = SVC(kernel='poly', degree=8)
# ----> 3 svclassifier.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     760     else:
#     761         y = column_or_1d(y, warn=True)
# --> 762         _assert_all_finite(y)
#     763     if y_numeric and y.dtype.kind == 'O':
#     764         y = y.astype(np.float64)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
y_pred = svclassifier.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-102-a5a62e7485a7> in <module>
# ----> 1 y_pred = svclassifier.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in predict(self, X)
#     574             Class labels for samples in X.
#     575         """
# --> 576         y = super(BaseSVC, self).predict(X)
#     577         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     578
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in predict(self, X)
#     323         y_pred : array, shape (n_samples,)
#     324         """
# --> 325         X = self._validate_for_predict(X)
#     326         predict = self._sparse_predict if self._sparse else self._dense_predict
#     327         return predict(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in _validate_for_predict(self, X)
#     453
#     454     def _validate_for_predict(self, X):
# --> 455         check_is_fitted(self, 'support_')
#     456
#     457         X = check_array(X, accept_sparse='csr', dtype=np.float64, order="C",
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: This SVC instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-f0fc2fa23a45> in <module>
#       1 from sklearn.metrics import classification_report, confusion_matrix
# ----> 2 print(confusion_matrix(y_test, y_pred))
#       3 print(classification_report(y_test, y_pred))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [495, 15]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# C:\Users\DPE\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\DPE\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\DPE\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-3d6bdcea431e> in <module>
#       2
#       3 lda = LDA(n_components=1)
# ----> 4 X_train = lda.fit_transform(X_train, y_train)
#       5 X_test = lda.transform(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
# --> 467             return self.fit(X, y, **fit_params).transform(X)
#     468
#     469
#
# ~\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py in fit(self, X, y)
#     427             Target values.
#     428         """
# --> 429         X, y = check_X_y(X, y, ensure_min_samples=2, estimator=self)
#     430         self.classes_ = unique_labels(y)
#     431         n_samples, _ = X.shape
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     760     else:
#     761         y = column_or_1d(y, warn=True)
# --> 762         _assert_all_finite(y)
#     763     if y_numeric and y.dtype.kind == 'O':
#     764         y = y.astype(np.float64)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
# Out:
# C:\Users\DPE\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-1dd2fd8760ac> in <module>
#       3 classifier = RandomForestClassifier(max_depth=2, random_state=0)
#       4
# ----> 5 classifier.fit(X_train, y_train)
#       6 y_pred = classifier.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     249         # Validate or convert input data
#     250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
# --> 251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#     253             sample_weight = check_array(sample_weight, ensure_2d=False)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy' + str(accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-ab5f378f9afe> in <module>
#       2 from sklearn.metrics import accuracy_score
#       3
# ----> 4 cm = confusion_matrix(y_test, y_pred)
#       5 print(cm)
#       6 print('Accuracy' + str(accuracy_score(y_test, y_pred)))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [495, 15]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-166daf9a5ec4> in <module>
#       1 X_train = sm.add_constant(tips.weaptype1)
# ----> 2 est = smf.Logit(y.ravel(), X_train).fit()
#       3 est.summary2().tables[1]
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in __init__(self, endog, exog, **kwargs)
#     419         if (not issubclass(self.__class__, MultinomialModel) and
#     420                 not np.all((self.endog >= 0) & (self.endog <= 1))):
# --> 421             raise ValueError("endog must be in the unit interval.")
#     422
#     423
#
# ValueError: endog must be in the unit interval.

# %%
tips = tips[pd.notnull(tips['weaptype1'])],

# %%
X_train = sm.add_constant(tips.attacktype1)
est = smf.Logit(y.ravel(), X_train).fit()
est.summary2().tables[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-ea75a3ea25e2> in <module>
# ----> 1 X_train = sm.add_constant(tips.attacktype1)
#       2 est = smf.Logit(y.ravel(), X_train).fit()
#       3 est.summary2().tables[1]
#
# AttributeError: 'tuple' object has no attribute 'attacktype1'
